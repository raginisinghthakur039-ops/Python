# %%
print("sorry")
# Out:
# sorry

# %%
x=5
y=7
z=5
print(id(x),id(y),id(z))
# Out:
# 140718073095416 140718073095480 140718073095416

# %%
length = int(input("Enter length:"))
breadth  =int(input("Enter breadth:"))
area = length * breadth
print("Area of the rectangle is:=",area)
# Out:
# Area of the rectangle is:= 8

# %%
c=int(input("Enter the degree celsius value:"))
f=9/5*c+32
print("The degree fahrenheit value is:=",f)
# Out:
# The degree fahrenheit value is:= 41.0
